# %%
import pandas as pd
from sklearn import linear_model
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Clean Data.csv')
X_data = data.drop(columns='price')
Y_data = data['price']

# %%
data.head()
# Out:
#    Unnamed: 0  price  resid_area  air_qual  room_num   age  dist1  teachers  \
# 0           0   24.0       32.31     0.538     6.575  65.2   4.35      24.7
# 1           1   21.6       37.07     0.469     6.421  78.9   4.99      22.2
# 2           2   34.7       37.07     0.469     7.185  61.1   5.03      22.2
# 3           3   33.4       32.18     0.458     6.998  45.8   6.21      21.3
# 4           4   36.2       32.18     0.458     7.147  54.2   6.16      21.3
#
#    n_hos_beds     parks  airport_NO  airport_YES  poor_prop_log  \
# 0       5.480  0.049347           0            1       1.788421
# 1       7.332  0.046146           1            0       2.316488
# 2       7.394  0.045764           1            0       1.615420
# 3       9.268  0.047151           0            1       1.371181
# 4       8.824  0.039474           1            0       1.845300
#
#    crime_rate_log
# 0        0.006300
# 1        0.026944
# 2        0.026924
# 3        0.031857
# 4        0.066770

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_data, Y_data, train_size=0.9)

# %%
alp = np.logspace(-9, 6, 150)
RidgeCV_model = linear_model.RidgeCV(alphas=alp)
RidgeCV_model.fit(X_train, Y_train)
alpha_RidgeCV = RidgeCV_model.alpha_

# %%
Y_predicted = RidgeCV_model.predict(X_test)

print("Coefficients:", RidgeCV_model.coef_)
print("Mean Squared Error : %.2f" %mean_squared_error(
    y_true= Y_test,
    y_pred= Y_predicted
))
print("Coefficient of determination : %.2f" %r2_score(
    y_true= Y_test,
    y_pred= Y_predicted
))
# Out:
# Coefficients: [ 1.75368984e-03 -3.26513372e-02 -1.74554680e+01  2.65521689e+00
#   3.10184919e-02 -1.08540910e+00  7.98975232e-01  2.78614574e-01
#   2.55237701e+01 -6.08081996e-01  6.08081996e-01 -1.09450284e+01
#  -1.83514631e-01]
# Mean Squared Error : 14.14
# Coefficient of determination : 0.74

# %%
#Visualising Predicted And Actual Data Differences
print(len(X_test), len(Y_test), len(Y_predicted))
# Out:
# 51 51 51

# %%
plt.scatter(
    x = X_test['room_num'],
    y = Y_test,
    color = "black",
    label = 'Actual'
)
plt.scatter(
    X_test['room_num'],
    Y_predicted,
    color = "red",
    label = 'Predicted'

)
plt.legend()
plt.xlabel('Rooms')
plt.ylabel('Price')
plt.title('Price vs Rooms Scatter on test set')
plt.xticks(())
plt.yticks(())
plt.savefig('Price(Actual And Predicted) vs Rooms')
plt.show()

# %%
plt.scatter(
    x = X_test['poor_prop_log'],
    y = Y_test,
    color = "black",
    label = 'Actual'
)
plt.scatter(
    X_test['poor_prop_log'],
    Y_predicted,
    color = "red",
    label = 'Predicted'

)
plt.legend()
plt.xlabel('Log Of Poor Propotion')
plt.ylabel('Price')
plt.title('Price vs Poor Proportion Scatter on test set')
plt.xticks(())
plt.yticks(())
plt.savefig('Price(Actual And Predicted) vs Poor Prop')
plt.show()

# %%
#Project Finished For Now
